# %% [markdown]
# # Installation

# %% [markdown]
# ``fMRI-HA`` is installable via ``pip``:

# %%
pip install fmriha

# %% [markdown]
# Alternatively, you can install the most up-to-date version of from GitHub:

# %%
git clone https://github.com/SinofWarth/GonglabHyperAligement.git

# %% [markdown]
# If you are a Windows user, you can also download the executable (GUI) version of ``fMRI-HA`` from xxx.
